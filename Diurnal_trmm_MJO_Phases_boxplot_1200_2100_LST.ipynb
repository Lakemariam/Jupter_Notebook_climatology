# %% [markdown]
# # Import some liberaries

# %%
# %matplotlib notebook
import netCDF4
from netCDF4 import Dataset
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
from matplotlib.font_manager import FontProperties

# %% [markdown]
# # Read land, coast, and sea data of TRMM with respect to MJO phases

# %%
# first column panel plot for 1200 LST
f1 = Dataset('djf_trmm_ph1_land_03.nc', mode='r')
f2 = Dataset('djf_trmm_ph2_land_03.nc', mode='r')
f3 = Dataset('djf_trmm_ph3_land_03.nc', mode='r')
f4 = Dataset('djf_trmm_ph4_land_03.nc', mode='r')
f5 = Dataset('djf_trmm_ph5_land_03.nc', mode='r')
f6 = Dataset('djf_trmm_ph6_land_03.nc', mode='r')
f7 = Dataset('djf_trmm_ph7_land_03.nc', mode='r')
f8 = Dataset('djf_trmm_ph8_land_03.nc', mode='r')

data1 = [f1.variables['precip'],f2.variables['precip'],f3.variables['precip'],f4.variables['precip'], \
       f5.variables['precip'],f6.variables['precip'],f7.variables['precip'],f8.variables['precip']]

f9 =  Dataset('djf_trmm_ph1_coast_03.nc', mode='r')
f10 = Dataset('djf_trmm_ph2_coast_03.nc', mode='r')
f11 = Dataset('djf_trmm_ph3_coast_03.nc', mode='r')
f12 = Dataset('djf_trmm_ph4_coast_03.nc', mode='r')
f13 = Dataset('djf_trmm_ph5_coast_03.nc', mode='r')
f14 = Dataset('djf_trmm_ph6_coast_03.nc', mode='r')
f15 = Dataset('djf_trmm_ph7_coast_03.nc', mode='r')
f16 = Dataset('djf_trmm_ph8_coast_03.nc', mode='r')

data2 = [f9.variables['precip'],f10.variables['precip'],f11.variables['precip'],f12.variables['precip'], \
       f13.variables['precip'],f14.variables['precip'],f15.variables['precip'],f16.variables['precip']]

f17 = Dataset('djf_trmm_ph1_sea_03.nc', mode='r')
f18 = Dataset('djf_trmm_ph2_sea_03.nc', mode='r')
f19 = Dataset('djf_trmm_ph3_sea_03.nc', mode='r')
f20 = Dataset('djf_trmm_ph4_sea_03.nc', mode='r')
f21 = Dataset('djf_trmm_ph5_sea_03.nc', mode='r')
f22 = Dataset('djf_trmm_ph6_sea_03.nc', mode='r')
f23 = Dataset('djf_trmm_ph7_sea_03.nc', mode='r')
f24 = Dataset('djf_trmm_ph8_sea_03.nc', mode='r')

data3 = [f17.variables['precip'],f18.variables['precip'],f19.variables['precip'],f20.variables['precip'], \
       f21.variables['precip'],f22.variables['precip'],f23.variables['precip'],f24.variables['precip']]


# Second column panel plot for 2100 LST

x1 = Dataset('djf_trmm_ph1_land_12.nc', mode='r')
x2 = Dataset('djf_trmm_ph2_land_12.nc', mode='r')
x3 = Dataset('djf_trmm_ph3_land_12.nc', mode='r')
x4 = Dataset('djf_trmm_ph4_land_12.nc', mode='r')
x5 = Dataset('djf_trmm_ph5_land_12.nc', mode='r')
x6 = Dataset('djf_trmm_ph6_land_12.nc', mode='r')
x7 = Dataset('djf_trmm_ph7_land_12.nc', mode='r')
x8 = Dataset('djf_trmm_ph8_land_12.nc', mode='r')

data4 = [x1.variables['precip'],x2.variables['precip'],x3.variables['precip'],x4.variables['precip'], \
       x5.variables['precip'],x6.variables['precip'],x7.variables['precip'],x8.variables['precip']]

x9 =  Dataset('djf_trmm_ph1_coast_12.nc', mode='r')
x10 = Dataset('djf_trmm_ph2_coast_12.nc', mode='r')
x11 = Dataset('djf_trmm_ph3_coast_12.nc', mode='r')
x12 = Dataset('djf_trmm_ph4_coast_12.nc', mode='r')
x13 = Dataset('djf_trmm_ph5_coast_12.nc', mode='r')
x14 = Dataset('djf_trmm_ph6_coast_12.nc', mode='r')
x15 = Dataset('djf_trmm_ph7_coast_12.nc', mode='r')
x16 = Dataset('djf_trmm_ph8_coast_12.nc', mode='r')

data5 = [x9.variables['precip'],x10.variables['precip'],x11.variables['precip'],x12.variables['precip'], \
       x13.variables['precip'],x14.variables['precip'],x15.variables['precip'],x16.variables['precip']]

x17 = Dataset('djf_trmm_ph1_sea_12.nc', mode='r')
x18 = Dataset('djf_trmm_ph2_sea_12.nc', mode='r')
x19 = Dataset('djf_trmm_ph3_sea_12.nc', mode='r')
x20 = Dataset('djf_trmm_ph4_sea_12.nc', mode='r')
x21 = Dataset('djf_trmm_ph5_sea_12.nc', mode='r')
x22 = Dataset('djf_trmm_ph6_sea_12.nc', mode='r')
x23 = Dataset('djf_trmm_ph7_sea_12.nc', mode='r')
x24 = Dataset('djf_trmm_ph8_sea_12.nc', mode='r')

data6 = [x17.variables['precip'],x18.variables['precip'],x19.variables['precip'],x20.variables['precip'], \
       x21.variables['precip'],x22.variables['precip'],x23.variables['precip'],x24.variables['precip']]

# %% [markdown]
# # Plot the data using panel plots of box plot

# %%
# set the panel plot size and orientation
# write the title of respective panel plots

fig, ax = plt.subplots(3,2, sharex=True, sharey=True, figsize=(12, 12))
font = FontProperties()
font.set_size('xx-large')

fig.text(0.5, 0.04, 'MJO Phases', ha='center', fontproperties=font)
fig.text(0.04, 0.5, 'Precipitation (mm/hr)', va='center', rotation='vertical', fontproperties=font)

# Assign position of each plots to be assigned
ax[0,0].boxplot(data1, showfliers=False)
ax[0,0].text(0.7, 1.0, 'a) Land', fontsize=15)
ax[0,0].set_title('TMPA and MJO Phases at 1200 LST', fontproperties=font)
ax[0,0].axis([1,8,0,1.1])

ax[1,0].boxplot(data2, showfliers=False)
ax[1,0].text(0.7, 1.0, 'b) Coast', fontsize=15)

ax[2,0].boxplot(data3, showfliers=False)
ax[2,0].text(0.7, 1.0, 'c) Sea', fontsize=15)

# ssecond column
# Assign position of each plots to be assigned
ax[0,1].boxplot(data4, showfliers=False)
ax[0,1].text(0.7, 1.0, 'a) Land', fontsize=15)
ax[0,1].set_title('TMPA and MJO Phases at 2100 LST', fontproperties=font)

ax[1,1].boxplot(data5, showfliers=False)
ax[1,1].text(0.7, 1.0, 'b) Coast', fontsize=15)

ax[2,1].boxplot(data6, showfliers=False)
ax[2,1].text(0.7, 1.0, 'c) Sea', fontsize=15)

x=np.array([1,2,3,4,5,6,7,8])
my_xticks = ['Ph1','Ph2','Ph3','Ph4','Ph5','Ph6','Ph7','Ph8']
plt.xticks(x,my_xticks)

# Customize panel plot

plt.subplots_adjust(hspace=0.05, wspace=0.05)
plt.show()
plt.savefig('Diurnal_trmm_MJO_Boxplot_12_21LST.png')
# Out:
# <img src="data:image/png;base64,..." width="1200">
